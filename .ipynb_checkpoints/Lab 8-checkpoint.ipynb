# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Machine Learning - 2301CS621</b></center>
#
# <center><b><h1>Lab - 8</b></center>
# <pre>

# %% [markdown]
# # import necessary libraries

# %% [markdown]
# # Import diabetes.csv data ser using sklearn

# %%
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age       Outcome
# 0                       0.627   50      Diabetic
# 1                       0.351   31  Non Diabetic
# 2                       0.672   32      Diabetic
# 3                       0.167   21  Non Diabetic
# 4                       2.288   33      Diabetic
# ..                        ...  ...           ...
# 763                     0.171   63  Non Diabetic
# 764                     0.340   27  Non Diabetic
# 765                     0.245   30  Non Diabetic
# 766                     0.349   47      Diabetic
# 767                     0.315   23  Non Diabetic
#
# [768 rows x 9 columns]

# %% [markdown]
# # Check the distribution of the target

# %%
# Out:
# Non Diabetic    500
# Diabetic        268
# Name: Outcome, dtype: int64

# %% [markdown]
# # Replace zeros with NaN for specific columns

# %%
# Out:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %% [markdown]
# # Check for missing values

# %% [markdown]
# # Fill missing values with median

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# # Visualize Distributions

# %%
# Out:
# /Users/jayesh/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Convert Targer data into interger code

# %%
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0    125.0  33.6
# 1              1     85.0           66.0           29.0    125.0  26.6
# 2              8    183.0           64.0           29.0    125.0  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0    125.0  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0           29.0    125.0  30.1
# 767            1     93.0           70.0           31.0    125.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# # Divide the data into input and output

# %% [markdown]
# # Splitting the dataset into the Training set and Test set

# %% [markdown]
# # Create Model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %% [markdown]
# # Fitting DecisionTreeClassifier   on dataset

# %%
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Display Decision Tree

# %%
# Out:
# [Text(0.5508261494252874, 0.96875, 'X[1] <= 154.5\ngini = 0.45\nsamples = 537\nvalue = [353, 184]'),
#  Text(0.22557471264367815, 0.90625, 'X[1] <= 107.5\ngini = 0.378\nsamples = 447\nvalue = [334, 113]'),
#  Text(0.1235632183908046, 0.84375, 'X[7] <= 25.5\ngini = 0.172\nsamples = 200\nvalue = [181, 19]'),
#  Text(0.11206896551724138, 0.78125, 'gini = 0.0\nsamples = 88\nvalue = [88, 0]'),
#  Text(0.13505747126436782, 0.78125, 'X[4] <= 154.0\ngini = 0.282\nsamples = 112\nvalue = [93, 19]'),
#  Text(0.11206896551724138, 0.71875, 'X[5] <= 50.9\ngini = 0.237\nsamples = 102\nvalue = [88, 14]'),
#  Text(0.10057471264367816, 0.65625, 'X[5] <= 26.35\ngini = 0.224\nsamples = 101\nvalue = [88, 13]'),
#  Text(0.08908045977011494, 0.59375, 'gini = 0.0\nsamples = 28\nvalue = [28, 0]'),
#  Text(0.11206896551724138, 0.59375, 'X[6] <= 1.16\ngini = 0.293\nsamples = 73\nvalue = [60, 13]'),
#  Text(0.08908045977011494, 0.53125, 'X[1] <= 89.5\ngini = 0.265\nsamples = 70\nvalue = [59, 11]'),
#  Text(0.07758620689655173, 0.46875, 'gini = 0.0\nsamples = 22\nvalue = [22, 0]'),
#  Text(0.10057471264367816, 0.46875, 'X[0] <= 6.5\ngini = 0.353\nsamples = 48\nvalue = [37, 11]'),
#  Text(0.06321839080459771, 0.40625, 'X[7] <= 50.0\ngini = 0.251\nsamples = 34\nvalue = [29, 5]'),
#  Text(0.05172413793103448, 0.34375, 'X[1] <= 90.5\ngini = 0.213\nsamples = 33\nvalue = [29, 4]'),
#  Text(0.022988505747126436, 0.28125, 'X[2] <= 70.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.011494252873563218, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.034482758620689655, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08045977011494253, 0.28125, 'X[7] <= 35.5\ngini = 0.175\nsamples = 31\nvalue = [28, 3]'),
#  Text(0.05747126436781609, 0.21875, 'X[3] <= 21.5\ngini = 0.087\nsamples = 22\nvalue = [21, 1]'),
#  Text(0.04597701149425287, 0.15625, 'X[5] <= 31.85\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.034482758620689655, 0.09375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.05747126436781609, 0.09375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06896551724137931, 0.15625, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.10344827586206896, 0.21875, 'X[7] <= 36.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.09195402298850575, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11494252873563218, 0.15625, 'X[6] <= 0.29\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.10344827586206896, 0.09375, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.12643678160919541, 0.09375, 'X[1] <= 99.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.11494252873563218, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.13793103448275862, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07471264367816093, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13793103448275862, 0.40625, 'X[7] <= 36.5\ngini = 0.49\nsamples = 14\nvalue = [8, 6]'),
#  Text(0.12643678160919541, 0.34375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.14942528735632185, 0.34375, 'X[2] <= 84.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.13793103448275862, 0.28125, 'X[3] <= 35.0\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.12643678160919541, 0.21875, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.14942528735632185, 0.21875, 'X[1] <= 102.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.13793103448275862, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16091954022988506, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16091954022988506, 0.28125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.13505747126436782, 0.53125, 'X[2] <= 69.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1235632183908046, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14655172413793102, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1235632183908046, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15804597701149425, 0.71875, 'X[3] <= 27.0\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.14655172413793102, 0.65625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.16954022988505746, 0.65625, 'X[2] <= 73.0\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.15804597701149425, 0.59375, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.1810344827586207, 0.59375, 'X[5] <= 33.3\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.16954022988505746, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1925287356321839, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3275862068965517, 0.84375, 'X[5] <= 26.95\ngini = 0.471\nsamples = 247\nvalue = [153, 94]'),
#  Text(0.1925287356321839, 0.78125, 'X[1] <= 137.5\ngini = 0.042\nsamples = 47\nvalue = [46, 1]'),
#  Text(0.1810344827586207, 0.71875, 'gini = 0.0\nsamples = 40\nvalue = [40, 0]'),
#  Text(0.20402298850574713, 0.71875, 'X[2] <= 56.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.1925287356321839, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.21551724137931033, 0.65625, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.46264367816091956, 0.78125, 'X[7] <= 27.5\ngini = 0.498\nsamples = 200\nvalue = [107, 93]'),
#  Text(0.27586206896551724, 0.71875, 'X[3] <= 28.5\ngini = 0.393\nsamples = 78\nvalue = [57, 21]'),
#  Text(0.23850574712643677, 0.65625, 'X[5] <= 40.7\ngini = 0.142\nsamples = 26\nvalue = [24, 2]'),
#  Text(0.22701149425287356, 0.59375, 'X[6] <= 1.133\ngini = 0.077\nsamples = 25\nvalue = [24, 1]'),
#  Text(0.21551724137931033, 0.53125, 'gini = 0.0\nsamples = 22\nvalue = [22, 0]'),
#  Text(0.23850574712643677, 0.53125, 'X[2] <= 66.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.22701149425287356, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.25, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.25, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3132183908045977, 0.65625, 'X[4] <= 137.5\ngini = 0.464\nsamples = 52\nvalue = [33, 19]'),
#  Text(0.27298850574712646, 0.59375, 'X[4] <= 97.0\ngini = 0.498\nsamples = 32\nvalue = [15, 17]'),
#  Text(0.2614942528735632, 0.53125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.28448275862068967, 0.53125, 'X[2] <= 85.5\ngini = 0.485\nsamples = 29\nvalue = [12, 17]'),
#  Text(0.27298850574712646, 0.46875, 'X[2] <= 78.0\ngini = 0.497\nsamples = 26\nvalue = [12, 14]'),
#  Text(0.2442528735632184, 0.40625, 'X[6] <= 0.183\ngini = 0.472\nsamples = 21\nvalue = [8, 13]'),
#  Text(0.22126436781609196, 0.34375, 'X[6] <= 0.145\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.20977011494252873, 0.28125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.23275862068965517, 0.28125, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.2672413793103448, 0.34375, 'X[1] <= 129.5\ngini = 0.391\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.2557471264367816, 0.28125, 'X[1] <= 115.5\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.2442528735632184, 0.21875, 'X[0] <= 5.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.23275862068965517, 0.15625, 'X[7] <= 26.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.22126436781609196, 0.09375, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.2442528735632184, 0.09375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2557471264367816, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2672413793103448, 0.21875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.27873563218390807, 0.28125, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.3017241379310345, 0.40625, 'X[7] <= 22.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.29022988505747127, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3132183908045977, 0.34375, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.2959770114942529, 0.46875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.35344827586206895, 0.59375, 'X[2] <= 54.0\ngini = 0.18\nsamples = 20\nvalue = [18, 2]'),
#  Text(0.33045977011494254, 0.53125, 'X[3] <= 38.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.31896551724137934, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.34195402298850575, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3764367816091954, 0.53125, 'X[0] <= 4.5\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(0.3649425287356322, 0.46875, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.3879310344827586, 0.46875, 'X[4] <= 150.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3764367816091954, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3994252873563218, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6494252873563219, 0.71875, 'X[5] <= 45.3\ngini = 0.484\nsamples = 122\nvalue = [50, 72]'),
#  Text(0.6379310344827587, 0.65625, 'X[2] <= 73.0\ngini = 0.491\nsamples = 115\nvalue = [50, 65]'),
#  Text(0.5402298850574713, 0.59375, 'X[4] <= 132.5\ngini = 0.444\nsamples = 57\nvalue = [19, 38]'),
#  Text(0.48563218390804597, 0.53125, 'X[7] <= 32.5\ngini = 0.361\nsamples = 38\nvalue = [9, 29]'),
#  Text(0.4454022988505747, 0.46875, 'X[2] <= 69.0\ngini = 0.49\nsamples = 14\nvalue = [6, 8]'),
#  Text(0.4224137931034483, 0.40625, 'X[3] <= 16.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.4109195402298851, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4339080459770115, 0.34375, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.46839080459770116, 0.40625, 'X[6] <= 0.187\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.45689655172413796, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.47988505747126436, 0.34375, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.5258620689655172, 0.46875, 'X[1] <= 151.5\ngini = 0.219\nsamples = 24\nvalue = [3, 21]'),
#  Text(0.514367816091954, 0.40625, 'X[4] <= 104.5\ngini = 0.159\nsamples = 23\nvalue = [2, 21]'),
#  Text(0.5028735632183908, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5258620689655172, 0.34375, 'X[0] <= 0.5\ngini = 0.087\nsamples = 22\nvalue = [1, 21]'),
#  Text(0.514367816091954, 0.28125, 'X[1] <= 120.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5028735632183908, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5258620689655172, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5373563218390804, 0.28125, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(0.5373563218390804, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5948275862068966, 0.53125, 'X[6] <= 0.737\ngini = 0.499\nsamples = 19\nvalue = [10, 9]'),
#  Text(0.5833333333333334, 0.46875, 'X[0] <= 2.5\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.5603448275862069, 0.40625, 'X[3] <= 25.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.5488505747126436, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5718390804597702, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6063218390804598, 0.40625, 'X[6] <= 0.155\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.5948275862068966, 0.34375, 'X[7] <= 28.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5833333333333334, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6063218390804598, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.617816091954023, 0.34375, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.6063218390804598, 0.46875, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.735632183908046, 0.59375, 'X[6] <= 0.397\ngini = 0.498\nsamples = 58\nvalue = [31, 27]'),
#  Text(0.6867816091954023, 0.53125, 'X[4] <= 127.5\ngini = 0.437\nsamples = 31\nvalue = [21, 10]'),
#  Text(0.6637931034482759, 0.46875, 'X[2] <= 84.5\ngini = 0.375\nsamples = 24\nvalue = [18, 6]'),
#  Text(0.6522988505747126, 0.40625, 'X[6] <= 0.278\ngini = 0.469\nsamples = 16\nvalue = [10, 6]'),
#  Text(0.6408045977011494, 0.34375, 'X[0] <= 5.5\ngini = 0.408\nsamples = 14\nvalue = [10, 4]'),
#  Text(0.6293103448275862, 0.28125, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.6522988505747126, 0.28125, 'X[0] <= 7.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.6408045977011494, 0.21875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6637931034482759, 0.21875, 'X[7] <= 37.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6522988505747126, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6752873563218391, 0.15625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6637931034482759, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6752873563218391, 0.40625, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.7097701149425287, 0.46875, 'X[6] <= 0.261\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.6982758620689655, 0.40625, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.7212643678160919, 0.40625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7844827586206896, 0.53125, 'X[2] <= 86.0\ngini = 0.466\nsamples = 27\nvalue = [10, 17]'),
#  Text(0.7557471264367817, 0.46875, 'X[0] <= 2.0\ngini = 0.5\nsamples = 18\nvalue = [9, 9]'),
#  Text(0.7442528735632183, 0.40625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7672413793103449, 0.40625, 'X[1] <= 132.5\ngini = 0.48\nsamples = 15\nvalue = [6, 9]'),
#  Text(0.7442528735632183, 0.34375, 'X[6] <= 0.603\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.7327586206896551, 0.28125, 'X[1] <= 127.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.7212643678160919, 0.21875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7442528735632183, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7557471264367817, 0.28125, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.7902298850574713, 0.34375, 'X[6] <= 0.58\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.7787356321839081, 0.28125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8017241379310345, 0.28125, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.8132183908045977, 0.46875, 'X[7] <= 49.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.8017241379310345, 0.40625, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.8247126436781609, 0.40625, 'X[7] <= 57.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8132183908045977, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8362068965517241, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6609195402298851, 0.65625, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.8760775862068966, 0.90625, 'X[5] <= 29.85\ngini = 0.333\nsamples = 90\nvalue = [19, 71]'),
#  Text(0.8247126436781609, 0.84375, 'X[1] <= 161.5\ngini = 0.497\nsamples = 13\nvalue = [7, 6]'),
#  Text(0.8132183908045977, 0.78125, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.8362068965517241, 0.78125, 'X[2] <= 83.0\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.8247126436781609, 0.71875, 'X[7] <= 62.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.8132183908045977, 0.65625, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.8362068965517241, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8477011494252874, 0.71875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9274425287356322, 0.84375, 'X[4] <= 85.0\ngini = 0.263\nsamples = 77\nvalue = [12, 65]'),
#  Text(0.915948275862069, 0.78125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9389367816091954, 0.78125, 'X[4] <= 527.5\ngini = 0.231\nsamples = 75\nvalue = [10, 65]'),
#  Text(0.9008620689655172, 0.71875, 'X[6] <= 0.206\ngini = 0.198\nsamples = 72\nvalue = [8, 64]'),
#  Text(0.8591954022988506, 0.65625, 'X[1] <= 176.0\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.8477011494252874, 0.59375, 'X[1] <= 159.0\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.8362068965517241, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8591954022988506, 0.53125, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.8706896551724138, 0.59375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9425287356321839, 0.65625, 'X[5] <= 46.1\ngini = 0.146\nsamples = 63\nvalue = [5, 58]'),
#  Text(0.9109195402298851, 0.59375, 'X[2] <= 93.0\ngini = 0.098\nsamples = 58\nvalue = [3, 55]'),
#  Text(0.882183908045977, 0.53125, 'X[3] <= 16.5\ngini = 0.069\nsamples = 56\nvalue = [2, 54]'),
#  Text(0.8591954022988506, 0.46875, 'X[3] <= 14.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8477011494252874, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8706896551724138, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9051724137931034, 0.46875, 'X[3] <= 26.5\ngini = 0.036\nsamples = 54\nvalue = [1, 53]'),
#  Text(0.8936781609195402, 0.40625, 'X[6] <= 0.612\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.882183908045977, 0.34375, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.9051724137931034, 0.34375, 'X[3] <= 23.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8936781609195402, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9166666666666666, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9166666666666666, 0.40625, 'gini = 0.0\nsamples = 46\nvalue = [0, 46]'),
#  Text(0.9396551724137931, 0.53125, 'X[7] <= 43.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9281609195402298, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9511494252873564, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9741379310344828, 0.59375, 'X[1] <= 163.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.9626436781609196, 0.53125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.985632183908046, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9770114942528736, 0.71875, 'X[3] <= 31.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.9655172413793104, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9885057471264368, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]')]

# %% [markdown]
# # Predict the x_test

# %% [markdown]
# # Display Training Accuracy

# %%
model.score(x_train,y_train)
# Out:
# 1.0

# %% [markdown]
# # Display Test Accuracy

# %%
model.score(x_test,y_test)
# Out:
# 0.7489177489177489
