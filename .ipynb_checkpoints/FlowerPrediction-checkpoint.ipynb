# %%
import joblib
import warnings
warnings.filterwarnings('ignore')

# %%
loaded_model = joblib.load("iris_decision_tree.pkl")

# %%
prediction = loaded_model.predict([[7.2,3.2,4.7,1.4]])

# %%
flower = {
    0:"setosa",
    1:"versicolor",
    2:"virginica"
}

# %%
print(f"\nThis Flower is {flower[prediction[0]]}")
# Out:
# This Flower is versicolor
